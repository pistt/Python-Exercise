# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight') # 制定画风风格
import warnings
warnings.filterwarnings('ignore') #将警告滤掉
# %matplotlib inline

# %%
data = pd.read_csv('data/train.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
f, ax = plt.subplots(1,2, figsize=(18, 8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived', data=data, ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
# 特征分析
data.groupby(['Sex', 'Survived'])['Survived'].agg('count')
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
data[['Sex', 'Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %%
pd.crosstab(data.Pclass, data.Survived, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_ff60abbe_d1a9_11ea_9560_b508317b39a1row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ff60abbe_d1a9_11ea_9560_b508317b39a1row0_col1 {
#             background-color:  #cee666;
#             color:  #000000;
#         }    #T_ff60abbe_d1a9_11ea_9560_b508317b39a1row0_col2 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_ff60abbe_d1a9_11ea_9560_b508317b39a1row1_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_ff60abbe_d1a9_11ea_9560_b508317b39a1row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ff60abbe_d1a9_11ea_9560_b508317b39a1row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ff60abbe_d1a9_11ea_9560_b508317b39a1row2_col0 {
#             background-color:  #60b066;
#             color:  #000000;
#         }    #T_ff60abbe_d1a9_11ea_9560_b508317b39a1row2_col1 {
#             background-color:  #dfef66;
#             color:  #000000;
#         }    #T_ff60abbe_d1a9_11ea_9560_b508317b39a1row2_col2 {
#             background-color:  #90c866;
#             color:  #000000;
#         }    #T_ff60abbe_d1a9_11ea_9560_b508317b39a1row3_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_ff60abbe_d1a9_11ea_9560_b508317b39a1row3_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_ff60abbe_d1a9_11ea_9560_b508317b39a1row3_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_ff60abbe_d1a9_11ea_9560_b508317b39a1" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ff60abbe_d1a9_11ea_9560_b508317b39a1level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_ff60abbe_d1a9_11ea_9560_b508317b39a1row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_ff60abbe_d1a9_11ea_9560_b508317b39a1row0_col1" class="data row0 col1" >136</td>
#                         <td id="T_ff60abbe_d1a9_11ea_9560_b508317b39a1row0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_ff60abbe_d1a9_11ea_9560_b508317b39a1level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_ff60abbe_d1a9_11ea_9560_b508317b39a1row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_ff60abbe_d1a9_11ea_9560_b508317b39a1row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_ff60abbe_d1a9_11ea_9560_b508317b39a1row1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_ff60abbe_d1a9_11ea_9560_b508317b39a1level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_ff60abbe_d1a9_11ea_9560_b508317b39a1row2_col0" class="data row2 col0" >372</td>
#                         <td id="T_ff60abbe_d1a9_11ea_9560_b508317b39a1row2_col1" class="data row2 col1" >119</td>
#                         <td id="T_ff60abbe_d1a9_11ea_9560_b508317b39a1row2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_ff60abbe_d1a9_11ea_9560_b508317b39a1level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_ff60abbe_d1a9_11ea_9560_b508317b39a1row3_col0" class="data row3 col0" >549</td>
#                         <td id="T_ff60abbe_d1a9_11ea_9560_b508317b39a1row3_col1" class="data row3 col1" >342</td>
#                         <td id="T_ff60abbe_d1a9_11ea_9560_b508317b39a1row3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32', '#FFDF00', '#D3D3D3'], ax=ax[0])
ax[0].set_title('Number of Passenger by Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %%
pd.crosstab([data.Sex, data.Survived], data.Pclass, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_7b94d466_d1ab_11ea_9560_b508317b39a1row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_7b94d466_d1ab_11ea_9560_b508317b39a1row0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_7b94d466_d1ab_11ea_9560_b508317b39a1row0_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_7b94d466_d1ab_11ea_9560_b508317b39a1row0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_7b94d466_d1ab_11ea_9560_b508317b39a1row1_col0 {
#             background-color:  #96cb66;
#             color:  #000000;
#         }    #T_7b94d466_d1ab_11ea_9560_b508317b39a1row1_col1 {
#             background-color:  #a3d166;
#             color:  #000000;
#         }    #T_7b94d466_d1ab_11ea_9560_b508317b39a1row1_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_7b94d466_d1ab_11ea_9560_b508317b39a1row1_col3 {
#             background-color:  #cfe766;
#             color:  #000000;
#         }    #T_7b94d466_d1ab_11ea_9560_b508317b39a1row2_col0 {
#             background-color:  #a7d366;
#             color:  #000000;
#         }    #T_7b94d466_d1ab_11ea_9560_b508317b39a1row2_col1 {
#             background-color:  #85c266;
#             color:  #000000;
#         }    #T_7b94d466_d1ab_11ea_9560_b508317b39a1row2_col2 {
#             background-color:  #6eb666;
#             color:  #000000;
#         }    #T_7b94d466_d1ab_11ea_9560_b508317b39a1row2_col3 {
#             background-color:  #85c266;
#             color:  #000000;
#         }    #T_7b94d466_d1ab_11ea_9560_b508317b39a1row3_col0 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_7b94d466_d1ab_11ea_9560_b508317b39a1row3_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_7b94d466_d1ab_11ea_9560_b508317b39a1row3_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_7b94d466_d1ab_11ea_9560_b508317b39a1row3_col3 {
#             background-color:  #f7fb66;
#             color:  #000000;
#         }    #T_7b94d466_d1ab_11ea_9560_b508317b39a1row4_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_7b94d466_d1ab_11ea_9560_b508317b39a1row4_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_7b94d466_d1ab_11ea_9560_b508317b39a1row4_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_7b94d466_d1ab_11ea_9560_b508317b39a1row4_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_7b94d466_d1ab_11ea_9560_b508317b39a1" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7b94d466_d1ab_11ea_9560_b508317b39a1level0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#                         <th id="T_7b94d466_d1ab_11ea_9560_b508317b39a1level1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_7b94d466_d1ab_11ea_9560_b508317b39a1row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_7b94d466_d1ab_11ea_9560_b508317b39a1row0_col1" class="data row0 col1" >6</td>
#                         <td id="T_7b94d466_d1ab_11ea_9560_b508317b39a1row0_col2" class="data row0 col2" >72</td>
#                         <td id="T_7b94d466_d1ab_11ea_9560_b508317b39a1row0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_7b94d466_d1ab_11ea_9560_b508317b39a1level1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_7b94d466_d1ab_11ea_9560_b508317b39a1row1_col0" class="data row1 col0" >91</td>
#                         <td id="T_7b94d466_d1ab_11ea_9560_b508317b39a1row1_col1" class="data row1 col1" >70</td>
#                         <td id="T_7b94d466_d1ab_11ea_9560_b508317b39a1row1_col2" class="data row1 col2" >72</td>
#                         <td id="T_7b94d466_d1ab_11ea_9560_b508317b39a1row1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_7b94d466_d1ab_11ea_9560_b508317b39a1level0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#                         <th id="T_7b94d466_d1ab_11ea_9560_b508317b39a1level1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_7b94d466_d1ab_11ea_9560_b508317b39a1row2_col0" class="data row2 col0" >77</td>
#                         <td id="T_7b94d466_d1ab_11ea_9560_b508317b39a1row2_col1" class="data row2 col1" >91</td>
#                         <td id="T_7b94d466_d1ab_11ea_9560_b508317b39a1row2_col2" class="data row2 col2" >300</td>
#                         <td id="T_7b94d466_d1ab_11ea_9560_b508317b39a1row2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_7b94d466_d1ab_11ea_9560_b508317b39a1level1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_7b94d466_d1ab_11ea_9560_b508317b39a1row3_col0" class="data row3 col0" >45</td>
#                         <td id="T_7b94d466_d1ab_11ea_9560_b508317b39a1row3_col1" class="data row3 col1" >17</td>
#                         <td id="T_7b94d466_d1ab_11ea_9560_b508317b39a1row3_col2" class="data row3 col2" >47</td>
#                         <td id="T_7b94d466_d1ab_11ea_9560_b508317b39a1row3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_7b94d466_d1ab_11ea_9560_b508317b39a1level0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_7b94d466_d1ab_11ea_9560_b508317b39a1level1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_7b94d466_d1ab_11ea_9560_b508317b39a1row4_col0" class="data row4 col0" >216</td>
#                         <td id="T_7b94d466_d1ab_11ea_9560_b508317b39a1row4_col1" class="data row4 col1" >184</td>
#                         <td id="T_7b94d466_d1ab_11ea_9560_b508317b39a1row4_col2" class="data row4 col2" >491</td>
#                         <td id="T_7b94d466_d1ab_11ea_9560_b508317b39a1row4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=data)
plt.show()

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
sns.violinplot("Pclass", "Age", hue="Survived", data=data, split=True, ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0, 110, 10))
sns.violinplot("Sex", "Age", hue="Survived", data=data, split=True, ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0, 110, 10))
plt.show()

# %%
data['Initial'] = 0
for i in data:
    data['Initial'] = data.Name.str.extract('([A-Za-z]+)\.')
    pd.crosstab(data.Initial, data.Sex).T.style.background_gradient(cmap='summer_r')

# %%
data['Initial'].replace(['Mlle', 'Mme', 'Ms', 'Dr', 'Major', 'Lady', 'Countess', 'Jonkheer', 'Col', 'Rev', 'Capt', 'Sir', 'Don'], ['Miss', 'Miss', 'Miss', 'Mr', 'Mr', 'Mrs', 'Mrs', 'Other', 'Other', 'Other', 'Mr', 'Mr', 'Mr'], inplace=True)

# %%
data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
#Missing value inputation
data.loc[(data.Age.isnull()) & (data.Initial == 'Mr'), 'Age'] = 33
data.loc[(data.Age.isnull()) & (data.Initial == 'Mrs'), 'Age'] = 36
data.loc[(data.Age.isnull()) & (data.Initial == 'Master'), 'Age'] = 5
data.loc[(data.Age.isnull()) & (data.Initial == 'Miss'), 'Age'] = 22
data.loc[(data.Age.isnull()) & (data.Initial == 'Other'), 'Age'] = 46
data.Age.isnull().any()
# Out:
# False

# %%
f, ax = plt.subplots(1, 2, figsize=(20, 10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0], bins=20, edgecolor='black', color='red')
ax[0].set_title('Survived = 0')
x1 = list(range(0, 85, 5))
ax[0].set_xticks(x1)
data[data['Survived']==1].Age.plot.hist(ax=ax[1], bins=20, edgecolor='black', color='green')
ax[1].set_title('Survived = 1')
x2 = list(range(0, 85, 5))
ax[1].set_xticks(x2)
plt.show()

# %%
sns.factorplot('Pclass', 'Survived', col='Initial', data=data)

# %%
pd.crosstab([data.Embarked, data.Pclass], [data.Sex, data.Survived], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row0_col0 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row0_col1 {
#             background-color:  #d2e866;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row0_col2 {
#             background-color:  #f2f866;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row0_col3 {
#             background-color:  #d8ec66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row0_col4 {
#             background-color:  #e8f466;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row1_col1 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row1_col2 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row1_col3 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row1_col4 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row2_col0 {
#             background-color:  #e6f266;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row2_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row2_col2 {
#             background-color:  #eef666;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row2_col3 {
#             background-color:  #e8f466;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row2_col4 {
#             background-color:  #edf666;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row3_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row3_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row3_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row3_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row3_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row4_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row4_col1 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row4_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row4_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row4_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row5_col0 {
#             background-color:  #e3f166;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row5_col1 {
#             background-color:  #e6f266;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row5_col2 {
#             background-color:  #ecf666;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row5_col3 {
#             background-color:  #f8fc66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row5_col4 {
#             background-color:  #ebf566;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row6_col0 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row6_col1 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row6_col2 {
#             background-color:  #e4f266;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row6_col3 {
#             background-color:  #bede66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row6_col4 {
#             background-color:  #dbed66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row7_col0 {
#             background-color:  #edf666;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row7_col1 {
#             background-color:  #bdde66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row7_col2 {
#             background-color:  #d3e966;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row7_col3 {
#             background-color:  #dcee66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row7_col4 {
#             background-color:  #d1e866;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row8_col0 {
#             background-color:  #52a866;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row8_col1 {
#             background-color:  #dcee66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row8_col2 {
#             background-color:  #81c066;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row8_col3 {
#             background-color:  #b0d866;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row8_col4 {
#             background-color:  #9acc66;
#             color:  #000000;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row9_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row9_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row9_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row9_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_6ea3a5ee_d1af_11ea_9560_b508317b39a1row9_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_6ea3a5ee_d1af_11ea_9560_b508317b39a1" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Sex</th>        <th class="col_heading level0 col0" colspan=2>female</th>        <th class="col_heading level0 col2" colspan=2>male</th>        <th class="col_heading level0 col4" >All</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >Survived</th>        <th class="col_heading level1 col0" >0</th>        <th class="col_heading level1 col1" >1</th>        <th class="col_heading level1 col2" >0</th>        <th class="col_heading level1 col3" >1</th>        <th class="col_heading level1 col4" ></th>    </tr>    <tr>        <th class="index_name level0" >Embarked</th>        <th class="index_name level1" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6ea3a5ee_d1af_11ea_9560_b508317b39a1level0_row0" class="row_heading level0 row0" rowspan=3>C</th>
#                         <th id="T_6ea3a5ee_d1af_11ea_9560_b508317b39a1level1_row0" class="row_heading level1 row0" >1</th>
#                         <td id="T_6ea3a5ee_d1af_11ea_9

# %%
sns.factorplot('Embarked', 'Survived', data=data)
fig = plt.gcf()
fig.set_size_inches(5, 3)
plt.show()

# %%
f, ax = plt.subplots(2, 2, figsize=(20, 15))
sns.countplot('Embarked', data=data, ax=ax[0, 0])
ax[0, 0].set_title('No. of Passengers Boarded')
sns.countplot('Embarked', hue='Sex', data=data, ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot('Embarked', hue='Survived', data=data, ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('Embarked', hue='Pclass', data=data, ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2, hspace=0.3)
plt.show()

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', col='Embarked', data=data)

# %%
data['Embarked'].fillna('S', inplace=True)
data.Embarked.isnull().any()
# Out:
# False

# %%
pd.crosstab([data.SibSp], data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_d869d74a_d1b0_11ea_9560_b508317b39a1row0_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_d869d74a_d1b0_11ea_9560_b508317b39a1row0_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_d869d74a_d1b0_11ea_9560_b508317b39a1row1_col0 {
#             background-color:  #c4e266;
#             color:  #000000;
#         }    #T_d869d74a_d1b0_11ea_9560_b508317b39a1row1_col1 {
#             background-color:  #77bb66;
#             color:  #000000;
#         }    #T_d869d74a_d1b0_11ea_9560_b508317b39a1row2_col0 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_d869d74a_d1b0_11ea_9560_b508317b39a1row2_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_d869d74a_d1b0_11ea_9560_b508317b39a1row3_col0 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_d869d74a_d1b0_11ea_9560_b508317b39a1row3_col1 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_d869d74a_d1b0_11ea_9560_b508317b39a1row4_col0 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_d869d74a_d1b0_11ea_9560_b508317b39a1row4_col1 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_d869d74a_d1b0_11ea_9560_b508317b39a1row5_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_d869d74a_d1b0_11ea_9560_b508317b39a1row5_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_d869d74a_d1b0_11ea_9560_b508317b39a1row6_col0 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_d869d74a_d1b0_11ea_9560_b508317b39a1row6_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_d869d74a_d1b0_11ea_9560_b508317b39a1" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >SibSp</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d869d74a_d1b0_11ea_9560_b508317b39a1level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d869d74a_d1b0_11ea_9560_b508317b39a1row0_col0" class="data row0 col0" >398</td>
#                         <td id="T_d869d74a_d1b0_11ea_9560_b508317b39a1row0_col1" class="data row0 col1" >210</td>
#             </tr>
#             <tr>
#                         <th id="T_d869d74a_d1b0_11ea_9560_b508317b39a1level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d869d74a_d1b0_11ea_9560_b508317b39a1row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_d869d74a_d1b0_11ea_9560_b508317b39a1row1_col1" class="data row1 col1" >112</td>
#             </tr>
#             <tr>
#                         <th id="T_d869d74a_d1b0_11ea_9560_b508317b39a1level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d869d74a_d1b0_11ea_9560_b508317b39a1row2_col0" class="data row2 col0" >15</td>
#                         <td id="T_d869d74a_d1b0_11ea_9560_b508317b39a1row2_col1" class="data row2 col1" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_d869d74a_d1b0_11ea_9560_b508317b39a1level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d869d74a_d1b0_11ea_9560_b508317b39a1row3_col0" class="data row3 col0" >12</td>
#                         <td id="T_d869d74a_d1b0_11ea_9560_b508317b39a1row3_col1" class="data row3 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_d869d74a_d1b0_11ea_9560_b508317b39a1level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d869d74a_d1b0_11ea_9560_b508317b39a1row4_col0" class="data row4 col0" >15</td>
#                         <td id="T_d869d74a_d1b0_11ea_9560_b508317b39a1row4_col1" class="data row4 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_d869d74a_d1b0_11ea_9560_b508317b39a1level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d869d74a_d1b0_11ea_9560_b508317b39a1row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_d869d74a_d1b0_11ea_9560_b508317b39a1row5_col1" class="data row5 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_d869d74a_d1b0_11ea_9560_b508317b39a1level0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_d869d74a_d1b0_11ea_9560_b508317b39a1row6_col0" class="data row6 col0" >7</td>
#                         <td id="T_d869d74a_d1b0_11ea_9560_b508317b39a1row6_col1" class="data row6 col1" >0</td>
#             </tr>
#     </tbody></table>

# %%
f, ax = plt.subplots(1, 2, figsize=(20, 8))
sns.barplot('SibSp', 'Survived', data=data, ax=ax[0])
ax[0].set_title('SibSp vs Survived')
sns.factorplot('SibSp', 'Survived', data=data, ax=ax[1])
ax[1].set_title('SibSp vs Survived')
plt.close(2)
plt.show()

# %%
f, ax = plt.subplots(1, 2, figsize=(20, 8))
sns.barplot('Parch', 'Survived', data=data, ax=ax[0])
ax[0].set_title('Parch vs Survived')
sns.factorplot('Parch', 'Survived', data=data, ax=ax[1])
ax[1].set_title('Parch vs Survived')
plt.close(2)
plt.show()

# %%
f, ax = plt.subplots(1,3, figsize=(20, 8))
sns.distplot(data[data['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')
sns.distplot(data[data['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')
sns.distplot(data[data['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()

# %%
# 特征之间的相关性
sns.heatmap(data.corr(), annot=True, cmap='RdYlGn', linewidths=0.2)
fig = plt.gcf()
fig.set_size_inches((10, 8))
plt.show()

# %%
data['Age_band'] = 0
data.loc[data['Age']<=16, 'Age_band'] = 0
data.loc[(data['Age']>16)&(data['Age']<=32), 'Age_band'] = 1
data.loc[(data['Age']>32)&(data['Age']<=48), 'Age_band'] = 2
data.loc[(data['Age']>48)&(data['Age']<=64), 'Age_band'] = 3
data.loc[data['Age']>64, 'Age_band'] = 4
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Initial  Age_band
# 0      0         A/5 21171   7.2500   NaN        S      Mr         1
# 1      0          PC 17599  71.2833   C85        C     Mrs         2
# 2      0  STON/O2. 3101282   7.9250   NaN        S    Miss         1
# 3      0            113803  53.1000  C123        S     Mrs         2
# 4      0            373450   8.0500   NaN        S      Mr         2

# %%
data['Age_band'].value_counts().to_frame().style.background_gradient(cmap='summer')
# Out:
# <style  type="text/css" >
#     #T_eddb313a_d1b2_11ea_9560_b508317b39a1row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_eddb313a_d1b2_11ea_9560_b508317b39a1row1_col0 {
#             background-color:  #d8ec66;
#             color:  #000000;
#         }    #T_eddb313a_d1b2_11ea_9560_b508317b39a1row2_col0 {
#             background-color:  #40a066;
#             color:  #000000;
#         }    #T_eddb313a_d1b2_11ea_9560_b508317b39a1row3_col0 {
#             background-color:  #289366;
#             color:  #000000;
#         }    #T_eddb313a_d1b2_11ea_9560_b508317b39a1row4_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_eddb313a_d1b2_11ea_9560_b508317b39a1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Age_band</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_eddb313a_d1b2_11ea_9560_b508317b39a1level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_eddb313a_d1b2_11ea_9560_b508317b39a1row0_col0" class="data row0 col0" >382</td>
#             </tr>
#             <tr>
#                         <th id="T_eddb313a_d1b2_11ea_9560_b508317b39a1level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_eddb313a_d1b2_11ea_9560_b508317b39a1row1_col0" class="data row1 col0" >325</td>
#             </tr>
#             <tr>
#                         <th id="T_eddb313a_d1b2_11ea_9560_b508317b39a1level0_row2" class="row_heading level0 row2" >0</th>
#                         <td id="T_eddb313a_d1b2_11ea_9560_b508317b39a1row2_col0" class="data row2 col0" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_eddb313a_d1b2_11ea_9560_b508317b39a1level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_eddb313a_d1b2_11ea_9560_b508317b39a1row3_col0" class="data row3 col0" >69</td>
#             </tr>
#             <tr>
#                         <th id="T_eddb313a_d1b2_11ea_9560_b508317b39a1level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_eddb313a_d1b2_11ea_9560_b508317b39a1row4_col0" class="data row4 col0" >11</td>
#             </tr>
#     </tbody></table>

# %%
sns.factorplot('Age_band', 'Survived', data=data, col='Pclass')
plt.show()

# %%
data['Family_Size'] = 0
data['Family_Size'] = data['Parch'] + data['SibSp']
data['Alone'] = 0
data.loc[data.Family_Size==0, 'Alone'] = 1

f, ax = plt.subplots(1, 2, figsize=(18, 6))
sns.factorplot('Family_Size', 'Survived', data=data, ax=ax[0])
ax[0].set_title('Family_Size vs Survived')
sns.factorplot('Alone', 'Survived', data=data, ax=ax[1])
ax[1].set_title('Alone vs Survived')
plt.close(2)
plt.close(3)
plt.show()

# %%
sns.factorplot('Alone', 'Survived', data=data, hue='Sex', col='Pclass')
plt.show()

# %%
data['Fare_Range'] = pd.qcut(data['Fare'], 4)
data.groupby(['Fare_Range'])['Survived'].mean().to_frame().style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_db15959e_d1b3_11ea_9560_b508317b39a1row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_db15959e_d1b3_11ea_9560_b508317b39a1row1_col0 {
#             background-color:  #b9dc66;
#             color:  #000000;
#         }    #T_db15959e_d1b3_11ea_9560_b508317b39a1row2_col0 {
#             background-color:  #54aa66;
#             color:  #000000;
#         }    #T_db15959e_d1b3_11ea_9560_b508317b39a1row3_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_db15959e_d1b3_11ea_9560_b508317b39a1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Survived</th>    </tr>    <tr>        <th class="index_name level0" >Fare_Range</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_db15959e_d1b3_11ea_9560_b508317b39a1level0_row0" class="row_heading level0 row0" >(-0.001, 7.91]</th>
#                         <td id="T_db15959e_d1b3_11ea_9560_b508317b39a1row0_col0" class="data row0 col0" >0.197309</td>
#             </tr>
#             <tr>
#                         <th id="T_db15959e_d1b3_11ea_9560_b508317b39a1level0_row1" class="row_heading level0 row1" >(7.91, 14.454]</th>
#                         <td id="T_db15959e_d1b3_11ea_9560_b508317b39a1row1_col0" class="data row1 col0" >0.303571</td>
#             </tr>
#             <tr>
#                         <th id="T_db15959e_d1b3_11ea_9560_b508317b39a1level0_row2" class="row_heading level0 row2" >(14.454, 31.0]</th>
#                         <td id="T_db15959e_d1b3_11ea_9560_b508317b39a1row2_col0" class="data row2 col0" >0.454955</td>
#             </tr>
#             <tr>
#                         <th id="T_db15959e_d1b3_11ea_9560_b508317b39a1level0_row3" class="row_heading level0 row3" >(31.0, 512.329]</th>
#                         <td id="T_db15959e_d1b3_11ea_9560_b508317b39a1row3_col0" class="data row3 col0" >0.581081</td>
#             </tr>
#     </tbody></table>

# %%
data['Fare_Cat'] = 0
data.loc[data['Fare']<=7.91, 'Fare_Cat'] = 0
data.loc[(data['Fare']>7.91)&(data['Fare']<=14.454), 'Fare_Cat'] = 1
data.loc[(data['Fare']>14.454)&(data['Fare']<=31.0), 'Fare_Cat'] = 2
data.loc[(data['Fare']>31.0)&(data['Fare']<=513), 'Fare_Cat'] = 3

# %%
sns.factorplot('Fare_Cat', 'Survived', hue='Sex', data=data)
plt.show()

# %%
# data['Sex'] = data['Sex'].replace(['male', 'female'], ["0", "1"])
# data['Sex'].replace(['male', 'female'], [0, 1], inplace=True)
data['Embarked'].replace(['S', 'C', 'Q'], [0, 1, 2], inplace=True)
data['Initial'].replace(['Mr', 'Mrs', 'Miss', 'Master', 'Other'], [0, 1, 2, 3, 4], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-4f2525bb5cec> in <module>
#       1 # data['Sex'] = data['Sex'].replace(['male', 'female'], ["0", "1"])
#       2 # data['Sex'].replace(['male', 'female'], [0, 1], inplace=True)
# ----> 3 data['Embarked'].replace(['S', 'C', 'Q'], [0, 1, 2], inplace=True)
#       4 data['Initial'].replace(['Mr', 'Mrs', 'Miss', 'Master', 'Other'], [0, 1, 2, 3, 4], inplace=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4176             limit=limit,
#    4177             regex=regex,
# -> 4178             method=method,
#    4179         )
#    4180
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6697                         dest_list=value,
#    6698                         inplace=inplace,
# -> 6699                         regex=regex,
#    6700                     )
#    6701
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in replace_list(self, src_list, dest_list, inplace, regex)
#     611             return _compare_or_regex_search(values, s, regex)
#     612
# --> 613         masks = [comp(s, regex) for i, s in enumerate(src_list)]
#     614
#     615         result_blocks = []
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#     611             return _compare_or_regex_search(values, s, regex)
#     612
# --> 613         masks = [comp(s, regex) for i, s in enumerate(src_list)]
#     614
#     615         result_blocks = []
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in comp(s, regex)
#     609                     maybe_convert_objects(values), s.asm8, regex
#     610                 )
# --> 611             return _compare_or_regex_search(values, s, regex)
#     612
#     613         masks = [comp(s, regex) for i, s in enumerate(src_list)]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in _compare_or_regex_search(a, b, regex)
#    1934
#    1935         raise TypeError(
# -> 1936             f"Cannot compare types {repr(type_names[0])} and {repr(type_names[1])}"
#    1937         )
#    1938     return result
#
# TypeError: Cannot compare types 'ndarray(dtype=int64)' and 'str'

# %%
data.drop(['Name', 'Age', 'Ticket', 'Fare', 'Cabin', 'Fare_Range', 'PassengerId'], axis=1, inplace=True)
sns.heatmap(data.corr(), annot=True, cmap='RdYlGn', linewidths=0.2, annot_kws={'size':20})
fig = plt.gcf()
fig.set_size_inches(18, 15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix

# %%
train, test = train_test_split(data, test_size=0.3, random_state=0, stratify=data['Survived'])
train_X = train[train.columns[1:]]
train_Y = train[train.columns[:1]]
test_X = test[test.columns[1:]]
test_Y = test[test.columns[:1]]
X = data[data.columns[1:]]
Y = data['Survived']

# %%
model = svm.SVC(kernel='rbf', C=1, gamma=0.1)
model.fit(train_X, train_Y)
prediction1 = model.predict(test_X)
print("Acc. for rbf SVM is ", metrics.accuracy_score(prediction1, test_Y))
# Out:
# Acc. for rbf SVM is  0.835820895522388
